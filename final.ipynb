# %% [markdown]
# <h1 style="font-size:60px;
#            color:orangered;
#            text-align:center;
#            border-bottom:3px solid orangered">
#     PROYECTO CIENCIA DE DATOS</h1>

# %% [markdown]
# # Tabla de contenido
#
# - [__Proyecto final 0__](#ind00)
# - [__Objetivo 1__](#ind01)
# - [__Contexto analitico 2__](#ind02)
# - [__Data acquisition 3__](#ind03)
# - [__Exploratory data analysis (EDA) 4__](#ind04)
# - [__Data wrangling 5__](#ind05)
# - [__Feature selection 6__](#ind06)
# - [__Machine learning 7__](#ind07)
# - [__Conclusion 8__](#ind08)

# %% [markdown]
# ---

# %% [markdown]
# # 0. Proyecto final

# %% [markdown]
# _¿Cual es la probabilidad que tengo de ganar o perder una partida de un videojuego?_ Esta, es la pregunta principal que vamos a investigar a lo largo de este proyecto. El juego Leagoe of Legend consta de dos equipos 5 vs 5 que el objetivo de cada equipo es destruir la base enemiga. Para esto, el mapa se compone por tres lineas en las cuales iran los jugadores. Existen multiples personajes para jugar en cada partida que reciben el nombre de campeones. Estos últimos se diferencias por categorias, role, funcion y habilidades. Dependiendo de cada campeon, tiene un impacto distinto en la partida. Entonces... ¿Como vamos a realizar este proyecto? Para el mismo, generaremos una base de datos en base a las Apis que nos provee el mismo videojuego. Gracias a ellas seremos capaces de observar una partida en curso y ver los jugadores de la misma. Una vez que tengamos esa misma, emplaremos multiples funciones para obtener el historial de las ultimas 10 partidas de cada uno de los jugadores, en base a estas observaremos el desempeno de ellos y analizaremos a los mismos, una vez que tengamos esto podremos analizar las probabilidad de ganar la partida que tiene cada uno de los equipos.

# %% [markdown]
# # 1. Objetivo

# %% [markdown]
# _¿Cual es la probabilidad de ganar o perder?_ Como  vimos en el apartado anterior este es el objetivo de este proyecto. Se quiere investigar las mukltiples variables que disponemos dentro de las APIs del League Of Legends, de ahora en adelante lo llamaremos lol, para asi de esta forma encontrar la coneccion que tenemops entre ellas a lo largo del historial del jugador. En base al historial historico de un jugador, analizaremos todas sus partidas para comenzar a deducir patrones, aspectos que se compartan. Algunos de ellos pueden ser con quien juega acompañado por ejemplo, mientras que otros pueden ser conceptos mas tecnicos dentro del mismo juego como el nivel de farmeo (hace referencia a la cantidad de subditos que elimino) entre muchos otros.
#
# Para la resolucion de esta problematica existen alguns preguntas que pueden comenzar a guiar el proyecto en un rumbo. Debajo se dejara un listado con las mismas:
#
# - ¿Cuantas partidas jugo el jugador en los ultimos 5 años?¿Cuantas por año?
# - ¿Cual es el KDA (kill, deaths, assistants) del mismo?¿Como fue evolucionando en cada año?
# - ¿Cuales son los campeones que más usa?¿Como evoluciono con cada uno (KDA con el campeon)?
# - ¿Cuales son los campeones con mayor nivel de maestria que posee?
# - ¿Cual es el nivel de farmeo del jugador?
# - ¿Cual es el nivel de vision del mapa del jugador?
# - ¿En que linea se desempeño mejor?¿Que clase de campeon empleo para ello?

# %% [markdown]
# # 2. Contexto analitico

# %% [markdown]
# Para este proyecto analizaremos el historial de partidas junto a otras caracteristicas de cada un jugador. Para obtener estos datos implementaremos el uso directo de las APIs proporcionadas por Riot Games (desarrolladora del juego). Entre ellas nos podemos encontrar los siguientes links que estaremos usando.
#
# __Developers home page__
# - https://developer.riotgames.com/
#
# __APIs de Riot Games__
# - https://developer.riotgames.com/apis#league-v4
#
# __APIs information__
# - https://developer.riotgames.com/docs/portal#_overview

# %% [markdown]
# # 3. Data acquisition

# %% [markdown]
# ## 3.1 Librerias

# %%
## Cargamos las librerias que seran nesarias
# Para trabajar los datos
import json
import requests
import pandas as pd
import numpy as np
from modules import utils as ut

# Para traer la api key
import os
from dotenv import load_dotenv

# Para eliminar los carteles warnings
import warnings as wn

# %%
# Importamos la api key
# Obtén la ruta absoluta del archivo .env
env_path = os.path.join(os.path.dirname('testing.ipynb'), 'conf', '.env')

# Carga las variables de entorno desde el archivo .env
load_dotenv(env_path)

# Accede a la variable de entorno
key_admin = os.getenv('key_admin')

# %% [markdown]
# ## 3.2 Base de datos desde API

# %%
partida01 = pd.read_csv('data/live_matchs/partida01.csv', delimiter=';', index_col=0)
partida02 = pd.read_csv('data/live_matchs/partida02.csv', delimiter=';', index_col=0)
partida03 = pd.read_csv('data/live_matchs/partida03.csv', delimiter=';', index_col=0)
partida04 = pd.read_csv('data/live_matchs/partida04.csv', delimiter=';', index_col=0)

# %%
df_games = pd.read_csv('data/df_games.csv')
# Out:
# C:\Users\herne\AppData\Local\Temp\ipykernel_6716\3473350840.py:1: DtypeWarning: Columns (106) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_games = pd.read_csv('data/df_games.csv')

# %% [markdown]
# <h2 style="font-size:30px;
#            color:orangered;
#            text-align:center;
#            border-bottom:3px solid orangered">
#     Controlamos que las partidas del historial tengan los mismos datos que las partidas en vivo</h2>

# %%
df_games
# Out:
#       index  assists  baronKills  bountyLevel  champExperience  champLevel
# 0         0        5           0            0             9886          12  \
# 1         1       13           0            0             9628          12
# 2         2        4           0            3            11620          14
# 3         3        6           0            1             9349          12
# 4         4       12           0            0             8559          11
# ...     ...      ...         ...          ...              ...         ...
# 7215      5        3           0            1             9522          12
# 7216      6        4           0            0             8160          11
# 7217      7        2           0            0            10103          13
# 7218      8        2           0            3             7777          11
# 7219      9        6           0            1             5047           9
#
#       championId championName  championTransform  consumablesPurchased  ...
# 0            126        Jayce                  0                     0  ...  \
# 1             64       LeeSin                  0                     4  ...
# 2              4  TwistedFate                  0                     2  ...
# 3            145        Kaisa                  0                     2  ...
# 4            526         Rell                  0                     6  ...
# ...          ...          ...                ...                   ...  ...
# 7215         147    Seraphine                  0                     2  ...
# 7216          80     Pantheon                  0                     1  ...
# 7217          84        Akali                  0                     1  ...
# 7218         895        Nilah                  0                     3  ...
# 7219          53   Blitzcrank                  0                     5  ...
#
#       killAfterHiddenWithAlly  killedChampTookFullTeamDamageSurvived
# 0                         NaN                                    NaN  \
# 1                         NaN                                    NaN
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
# 4                         NaN                                    NaN
# ...                       ...                                    ...
# 7215                      1.0                                    0.0
# 7216                      0.0                                    0.0
# 7217                      0.0                                    0.0
# 7218                      3.0                                    0.0
# 7219                      2.0                                    0.0
#
#       knockEnemyIntoTeamAndKill  pickKillWithAlly  saveAllyFromDeath
# 0                           NaN               NaN                NaN  \
# 1                           NaN               NaN                NaN
# 2                           NaN               NaN                NaN
# 3                           NaN               NaN                NaN
# 4                           NaN               NaN                NaN
# ...                         ...               ...                ...
# 7215                        0.0               4.0                0.0
# 7216                        0.0               6.0                0.0
# 7217                        0.0               3.0                0.0
# 7218                        2.0               8.0                0.0
# 7219                        1.0               6.0                0.0
#
#       survivedThreeImmobilizesInFight  tookLargeDamageSurvived
# 0                                 NaN                      NaN  \
# 1                                 NaN                      NaN
# 2                                 NaN                      NaN
# 3                                 NaN                      NaN
# 4                                 NaN                      NaN
# ...                               ...                      ...
# 7215                              0.0                      0.0
# 7216                              0.0                      0.0
# 7217                              0.0                      0.0
# 7218                              0.0                      0.0
# 7219                              0.0                      0.0
#
#       takedownsFirstXMinutes  killingSprees_y  playedChampSelectPosition
# 0                        NaN              NaN                        NaN
# 1                        NaN              NaN                        NaN
# 2                        NaN              NaN                        NaN
# 3                        NaN              NaN                        NaN
# 4                        NaN              NaN                        NaN
# ...                      ...              ...                        ...
# 7215                     4.0              NaN                        1.0
# 7216                     4.0              NaN                        1.0
# 7217                     4.0              1.0                        1.0
# 7218                     6.0              2.0                        1.0
# 7219                     4.0              NaN                        1.0
#
# [7220 rows x 251 columns]

# %%
partida01.columns
# Out:
# Index(['teamId', 'spell1Id', 'spell2Id', 'championId', 'profileIconId',
#        'summonerName', 'bot', 'summonerId', 'gameCustomizationObjects',
#        'perks.perkIds', 'perks.perkStyle', 'perks.perkSubStyle'],
#       dtype='object')

# %%
hist = ut.historial_partidas('GC Darius Brando')
hist
# Out:
# Se finalizo el proceso de transformacion para GC Darius Brando.
# ['LA2_1046969177',
#  'LA2_1047026520',
#  'LA2_1047190809',
#  'LA2_1047196252',
#  'LA2_1047201490',
#  'LA2_1047623638',
#  'LA2_1047708088',
#  'LA2_1047912604',
#  'LA2_1047927431',
#  'LA2_1047948109',
#  'LA2_1047965835',
#  'LA2_1048353870',
#  'LA2_1048949393',
#  'LA2_1048967527',
#  'LA2_1048992227',
#  'LA2_1050301354',
#  'LA2_1050336929',
#  'LA2_1050343664',
#  'LA2_1050844757',
#  'LA2_1053653664',
#  'LA2_1053659005',
#  'LA2_1053725241',
#  'LA2_1054150105',
#  'LA2_1056048544',
#  'LA2_1058018204',
#  'LA2_1061817621',
#  'LA2_1061872965',
#  'LA2_1063042999',
#  'LA2_1063092673',
#  'LA2_1063110244',
#  'LA2_1063173366',
#  'LA2_1063178027',
#  'LA2_1064378802',
#  'LA2_1064403058',
#  'LA2_1064435937',
#  'LA2_1064489380',
#  'LA2_1064491277',
#  'LA2_1064512698',
#  'LA2_1065780594',
#  'LA2_1065783848',
#  'LA2_1065816259',
#  'LA2_1065850597',
#  'LA2_1065915132',
#  'LA2_1065917007',
#  'LA2_1065928521',
#  'LA2_1065951346',
#  'LA2_1066000064',
#  'LA2_1066087993',
#  'LA2_1066091968',
#  'LA2_1066428959',
#  'LA2_1066434611',
#  'LA2_1066452675',
#  'LA2_1066496180',
#  'LA2_1066532725',
#  'LA2_1066555126',
#  'LA2_1066915927',
#  'LA2_1066941421',
#  'LA2_1067000200',
#  'LA2_1067239803',
#  'LA2_1067350363',
#  'LA2_1067783759',
#  'LA2_1067787675',
#  'LA2_1068108571',
# 3           0              2       13          0           0           0
# 4           1              6       30          0           0           0
# 5           0              1       14          0           0           0
# 6           0             12        5          0           0           0
# 7           0              5        7          0           0           0
# 8           0              0        8          0           0           0
# 9           0              1       11          0           0           0
#
#    bountyLevel  champExperience  champLevel  championId  ... turretTakedowns
# 0            0            17633          17           8  ...               5  \
# 1            0            14313          15          35  ...               0
# 2           17            20820          18         136  ...               5
# 3            0            16411          16         145  ...               4
# 4            0            13938          15          53  ...               2
# 5            0            14880          16         516  ...               1
# 6            0            14521          15         234  ...               1
# 7            0            14922          16          39  ...               1
# 8            0            13955          15         222  ...               1
# 9            2            13807          15          43  ...               1
#
#    turretsLost  unrealKills  visionClearedPings  visionScore
# 0            3            0                   0           17  \
# 1            3            0                   0           22
# 2            3            0                   0           13
# 3            3            0                   1           27
# 4            3            0                   1           67
# 5            8            0                   0           20
# 6            8            0                   0           30
# 7            8            0                   0           33
# 8            8            0                   0           18
# 9            8            0                   0           41
#
#    visionWardsBoughtInGame  wardsKilled  wardsPlaced    win         id_game
# 0                        0            2            8   True  LA2_1301881670
# 1                        0            2            4   True  LA2_1301881670
# 2                        0            1            7   True  LA2_1301881670
# 3                        0            5           10   True  LA2_1301881670
# 4                        1            4           29   True  LA2_1301881670
# 5                        1            1            8  False  LA2_1301881670
# 6                        5            2            5  False  LA2_1301881670
# 7                        6            3            9  False  LA2_1301881670
# 8                        1            0           12  False  LA2_1301881670
# 9                        0            3           22  False  LA2_1301881670
#
# [10 rows x 122 columns]

# %%
ut.detalle_challenge_partida(['LA2_1301881670'])
# Out:
#    12AssistStreakCount  abilityUses  acesBefore15Minutes
# 0                    0          456                    0  \
# 1                    0          216                    0
# 2                    0          208                    0
# 3                    0          204                    0
# 4                    2          131                    0
# 5                    0          195                    0
# 6                    0          373                    0
# 7                    0          363                    0
# 8                    0          155                    0
# 9                    0          230                    0
#
#    alliedJungleMonsterKills  baronBuffGoldAdvantageOverThreshold
# 0                         3                                  1.0  \
# 1                        51                                  1.0
# 2                         0                                  1.0
# 3                         1                                  1.0
# 4                         0                                  1.0
# 5                         0                                  NaN
# 6                        72                                  NaN
# 7                         2                                  NaN
# 8                         9                                  NaN
# 9                         0                                  NaN
#
#    baronTakedowns  blastConeOppositeOpponentCount  bountyGold  buffsStolen
# 0               0                               0         525            0  \
# 1               1                               0         150            1
# 2               1                               0         375            0
# 3               1                               0         150            1
# 4               1                               0           0            0
# 5               0                               0           0            0
# 6               0                               0         875            2
# 7               0                               0         450            1
# 8               0                               0           0            0
# 9               0                               0         150            0
#
#    completeSupportQuestInTime  ...  junglerKillsEarlyJungle
# 0                           0  ...                      NaN  \
# 1                           0  ...                      0.0
# 2                           0  ...                      NaN
# 3                           0  ...                      NaN
# 4                           0  ...                      NaN
# 5                           0  ...                      NaN
# 6                           0  ...                      0.0
# 7                           0  ...                      NaN
# 8                           0  ...                      NaN
# 9                           1  ...                      NaN
#
#    killsOnLanersEarlyJungleAsJungler  fastestLegendary  highestWardKills
# 0                                NaN               NaN               NaN  \
# 1                                4.0               NaN               NaN
# 2                                NaN       1635.029845               NaN
# 3                                NaN               NaN               1.0
# 4                                NaN               NaN               NaN
# 5                                NaN               NaN               NaN
# 6                                4.0               NaN               NaN
# 7                                NaN               NaN               NaN
# 8                                NaN               NaN               NaN
# 9                                NaN               NaN               NaN
#
#    soloTurretsLategame  controlWardTimeCoverageInRiverOrEnemyHalf
# 0                  NaN                                        NaN  \
# 1                  NaN                                        NaN
# 2                  NaN                                        NaN
# 3                  2.0                                        NaN
# 4                  NaN                                   0.813772
# 5                  NaN                                        NaN
# 6                  NaN                                   0.825422
# 7                  NaN                                   0.877191
# 8                  NaN                                   0.811522
# 9                  NaN                                        NaN
#
#    highestCrowdControlScore  fasterSupportQuestCompletion         id_game
# 0                       NaN                           NaN  LA2_1301881670  \
# 1                       NaN                           NaN  LA2_1301881670
# 2                       NaN                           NaN  LA2_1301881670
# 3                       NaN                           NaN  LA2_1301881670
# 4                       1.0                           NaN  LA2_1301881670
# 5                       NaN                           NaN  LA2_1301881670
# 6                       NaN                           NaN  LA2_1301881670
# 7                       NaN                           NaN  LA2_1301881670
# 8                       NaN                           NaN  LA2_1301881670
# 9                       NaN                           1.0  LA2_1301881670
#
#                                           summonerId
# 0    OFRslar8Gddqq-dmZSxI5KSB4mnR1TccZ-qIMEwFjckDmdg
# 1     K2twAA5gA-gMXY4YVq0szKaX-er9Hlhz8sitMu4lzN00Qw
# 2  UuoNbnfTvcLE92oDoFsSgpL4MRt8EEUiIyOTUHdTKkCrIj...
# 3     xFSyM3b5kdX6naAbEIT1ZpAU6yWSZVxar74uwwMxYZiXSQ
# 4    FVQH2Ku1IsMqpNtDkhjLAF7esiH2UDOGdACSXgWJEfD5GNU
# 5     03w6OhOJXa9JtJTgKcbLn_uay2pWIVDy3ooihK6gCBkGTA
# 6    he-D1TnFFED6TX3prBP45PZlgCpn2BjLb3mwu7XzyXtgpiE
# 7     NyTz6f8K7q9c4jhUAmBgLruSx6b6zx1Z1B1Fqq6hTCrFqA
# 8  oB4cUXKmbdGq2skGPd4Fy4ZtbfSjfv_v32Xo7ToVKeE1yW...
# 9       CZMrNyx2yMPE4A2i478sFd8HxsAuG5IJA7rpx6XXegxM
#
# [10 rows x 127 columns]

# %% [markdown]
# <h3 style="font-size:20px;
#            color:orangered;
#            text-align:left">
#     Debemos modificar la funcion de debajo para que dentro de los datos que nos traiga este incluido los datos de los Perks que uso cada uno de los jugadores.</h3>

# %%
def detalle_partidas(id_partida:str)->pd.DataFrame:
    
    # Establecemos una coneccion con la API para extraer los datos
    url = f"https://americas.api.riotgames.com/lol/match/v5/matches/{id_partida}?api_key={key_admin}"
    
    try:
        # Establecemos la coneccion con la api
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Error al obtener los datos de la partida {partida}.")
        else:
            None

        # Convertimos el json
        json_info = json.loads(response.text)

        # Comenzamos a transformar el json en un df
        match_information = pd.DataFrame(json_info['info']['participants'])
        
        # Reiniciamos el índice para evitar índices duplicados
        match_information.reset_index(drop=True, inplace=True)

        # Nos fijamos si existe la columna challenges
        if 'challenges'in match_information.columns: 

            # Desglozamos la columna que quedo como un diccionario
            match_information.drop(['challenges'], axis=1, inplace = True)
            
        else:
            None

        # Eliminamos las columnas que no nos sirven
        match_information.drop(['perks'], axis=1, inplace = True)

        # Establecemos una columna con el nombre del id de la partida
        match_information['id_game'] = id_partida
        print(f"Se finalizo el proceso para la partida {id_partida}")

        return match_information
    
    except Exception as e:
        print(f"Error al obtener los datos de la partida {id_partida}: {e}")
        return pd.DataFrame()

# %%
# Establecemos una coneccion con la API para extraer los datos
url = f"https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1301881670?api_key={key_admin}"

# Establecemos la coneccion con la api
response = requests.get(url)
if response.status_code != 200:
    print(f"Error al obtener los datos de la partida LA2_1301881670.")
else:
    None

# Convertimos el json
json_info = json.loads(response.text)

# Comenzamos a transformar el json en un df
match_information = pd.DataFrame(json_info['info']['participants'])

# Reiniciamos el índice para evitar índices duplicados
match_information.reset_index(drop=True, inplace=True)

# Nos fijamos si existe la columna challenges
if 'challenges'in match_information.columns: 

    # Desglozamos la columna que quedo como un diccionario
    match_information.drop(['challenges'], axis=1, inplace = True)
    
else:
    None

# Establecemos una columna con el nombre del id de la partida
match_information['id_game'] = 'LA2_1301881670'
print(f"Se finalizo el proceso para la partida LA2_1301881670")
# Out:
# Se finalizo el proceso para la partida LA2_1301881670

# %%
## Vamos a ir desglozando perks

# perks
# pd.json_normalize(match_information['perks'])
#  tenemos el estilo, perk defensivo, el felxible y el ofensivo

# 2 nivel de perks
# pd.json_normalize(pd.json_normalize(match_information['perks'])['styles'])
# Tenemos el estilo primario y el sub estilo, son valores 1 o 0

# 3 nivel de perks
# pd.json_normalize(pd.json_normalize(pd.json_normalize(match_information['perks'])['styles'])[1])
# Tenemos las seleciones, y el estilo de las mismas

# 4 nivel de perks
# pd.json_normalize(pd.json_normalize(pd.json_normalize(pd.json_normalize(match_information['perks'])['styles'])[1])['selections'])
# Tenemos los perks primarios y secundartios con sus var, tenemos un 1 oo un 0 en este caso

# 5 nivel de perks
pd.json_normalize(pd.json_normalize(pd.json_normalize(pd.json_normalize(pd.json_normalize(match_information['perks'])['styles'])[0])['selections'])[0])
# Tenemos el perk con los datos finales
# Out:
#    perk  var1  var2  var3
# 0  8230    30     0     0
# 1  8128  1373    22     0
# 2  8229  3472     0     0
# 3  8008    63     7     0
# 4  8439   771  1453     0
# 5  8437   920   580     0
# 6  8010   530     0     0
# 7  8010   754     0     0
# 8  8008    54     0     0
# 9  8128  1438    20     0

# %% [markdown]
# # I. Armado de la primera parte

# %% [markdown]
# ## La formula 1

# %%
# Creamos la funcion para que nos de los datos de la partida en viv
    
def live_match(nombre_jugador:str)->pd.DataFrame:
    
    #definimos algunas variables
    key = key_admin
    region = 'la2'
        
    # Creamos el df para almacenar los datos
    df_match = pd.DataFrame()
    
    # Obtenemos el id del jugador
    id = datos_invocador([nombre_jugador])['id'][0]
    print(f'El id del jugador es: {id}')
    
    # Conexion a la API
    url = f'https://{region}.api.riotgames.com/lol/spectator/v4/active-games/by-summoner/{id}?api_key={key_admin}'
    response = requests.get(url)
    if response.status_code != 200:
        print(f'Error al obtener datos de: {nombre_jugador}')
        return None
    
    # Lo transformamos en texto 
    texto = response.text
    
    # Lo transformamos en JSON y normalziamos con pd
    json_info = json.loads(texto)
    df_match = pd.json_normalize(json_info)
    
    print(f'Se finalizo el proceso para la partida de {nombre_jugador}')
    
        # Creamos el df vacio
    detalle_partida = pd.DataFrame()

    # Creamos el bucle para normalizar cada JSON    
    for i in range(0,10,1):
        
        # Normalizamos cada jugador
        player_normalize = pd.json_normalize(pd.json_normalize(df_match['participants'])[i])
        
        # Guardamos los datos
        detalle_partida = pd.concat([detalle_partida, player_normalize])
        
    ## Comenzamos con la limpieza de las columnas
    colstodrop = ['summonerName', 'profilelIconId', 'bot', 'gameCustomizationObjects']
    
    # Eliminamos las columnas que no empleamos
    detalle_partida.drop(columns=colstodrop)
    
    # 
    
    return incognita

# %%
partida01['perks.perkIds']
# Out:
# 0    [8229, 8226, 8210, 8237, 8126, 8106, 5008, 500...
# 0    [8010, 9111, 9104, 8299, 8473, 8451, 5005, 500...
# 0    [8112, 8139, 8138, 8135, 8226, 8237, 5005, 500...
# 0    [8369, 8304, 8321, 8347, 8143, 8135, 5008, 500...
# 0    [8005, 8009, 9103, 8014, 8345, 8304, 5005, 500...
# 0    [8229, 8226, 8210, 8237, 8345, 8347, 5008, 500...
# 0    [8439, 8401, 8473, 8242, 8345, 8347, 5007, 500...
# 0    [8230, 8226, 8210, 8236, 8009, 8014, 5005, 500...
# 0    [8008, 9111, 9104, 8014, 8126, 8106, 5005, 500...
# 0    [8437, 8446, 8473, 8451, 8126, 8106, 5005, 500...
# Name: perks.perkIds, dtype: object

# %%
partida01.head()
# Out:
#    teamId  spell1Id  spell2Id  championId  profileIconId    summonerName  \
# 0     100         4        14          99           5736        Foortune
# 0     100         4        12         150           4864      M1KE TYS0N
# 0     100         4        14         518           5434  AntonyKiller77
# 0     100         4        11         121           5755     PermAcànc3r
# 0     100         7         4          81             11     peneriko123
#
#      bot                                         summonerId  \
# 0  False    55MEpu53V7U8jG3j_umw8AuBPQAGpaj7EA7D75inMfyGxqM
# 0  False    FP95A4NcwZsbHYKATDFJpAMv8wzOpyxHxnfkadid94XNeCQ
# 0  False  VxqE0JuZi21SybY9oHea7IRvliueUMhz4sKn5cTZeCDDS2...
# 0  False  nU5_o77OIGTyHeMPNLC2mQ1L3khgtloykhzXa4HAuGHwuf...
# 0  False  8s9RcWQHEFrV4BjRNloqMVa8I5LCSGknzuzTuCM_cp64YS...
#
#   gameCustomizationObjects                                      perks.perkIds  \
# 0                       []  [8229, 8226, 8210, 8237, 8126, 8106, 5008, 500...
# 0                       []  [8010, 9111, 9104, 8299, 8473, 8451, 5005, 500...
# 0                       []  [8112, 8139, 8138, 8135, 8226, 8237, 5005, 500...
# 0                       []  [8369, 8304, 8321, 8347, 8143, 8135, 5008, 500...
# 0                       []  [8005, 8009, 9103, 8014, 8345, 8304, 5005, 500...
#
#    perks.perkStyle  perks.perkSubStyle
# 0             8200                8100
# 0             8000                8400
# 0             8100                8200
# 0             8300                8100
# 0             8000                8300

# %%
def champions_mastery(nombres_invocador:list)->pd.DataFrame():
       
    # Definimos algunas variables
    key = key_admin
    region = 'LA2'
    
    # Creamos un dataframe vacio
    df_summoner_mastery = pd.DataFrame()
    
    # Tenemos que obtener el id del dataframe obtenido anteriormente en base al nombre que ingresemos
    summoners_id =  nombres_invocador
    
    # Creamos un bucle for para que tome todos los nombre que indiquemos
    for summoner_id in summoners_id:
    
        # Nos conectamos a la api para obtener los datos
        api_for_mastery = f'https://{region}.api.riotgames.com/lol/champion-mastery/v4/champion-masteries/by-summoner/{summoner_id}?api_key={key}'

        response = requests.get(api_for_mastery)
        if response.status_code != 200:
            print(f"Error: no se pudo obtener la maestría de campeones del invocador {summoner_id}.")
            return None

        # Lo transformamos en un texto
        texto = response.text

        # Lo transformamos en un JSON y lo normalizamos en un pd.df
        json_info = json.loads(texto)
        mastery_information = pd.json_normalize(json_info)

        # Almacenamos los datos
        df_summoner_mastery = pd.concat([df_summoner_mastery, mastery_information], ignore_index=True)

        print(f'Se finalizo el proceso de transformacion para {summoner_id}.')
        
    # Eliminaremos las columnas que no sean necesarias
    colstodrop = ['puuid', 'lastPlayTime', 'championPointsSinceLastLevel', 'championPointsUntilNextLevel',
                  'chestGranted', 'tokensEarned']
    df_summoner_mastery.drop(columns=colstodrop)
    
    return df_summoner_mastery

champions_mastery(['55MEpu53V7U8jG3j_umw8AuBPQAGpaj7EA7D75inMfyGxqM'])
# Out:
# Se finalizo el proceso de transformacion para 55MEpu53V7U8jG3j_umw8AuBPQAGpaj7EA7D75inMfyGxqM.
#                                                  puuid  championId  \
# 0    66R8CIvUCknKjQdkU9lCromJDE3UFL6mKA4DVV5MNNFBSg...          99
# 1    66R8CIvUCknKjQdkU9lCromJDE3UFL6mKA4DVV5MNNFBSg...          21
# 2    66R8CIvUCknKjQdkU9lCromJDE3UFL6mKA4DVV5MNNFBSg...          25
# 3    66R8CIvUCknKjQdkU9lCromJDE3UFL6mKA4DVV5MNNFBSg...          43
# 4    66R8CIvUCknKjQdkU9lCromJDE3UFL6mKA4DVV5MNNFBSg...         145
# ..                                                 ...         ...
# 141  66R8CIvUCknKjQdkU9lCromJDE3UFL6mKA4DVV5MNNFBSg...          83
# 142  66R8CIvUCknKjQdkU9lCromJDE3UFL6mKA4DVV5MNNFBSg...         113
# 143  66R8CIvUCknKjQdkU9lCromJDE3UFL6mKA4DVV5MNNFBSg...         114
# 144  66R8CIvUCknKjQdkU9lCromJDE3UFL6mKA4DVV5MNNFBSg...          72
# 145  66R8CIvUCknKjQdkU9lCromJDE3UFL6mKA4DVV5MNNFBSg...         150
#
#      championLevel  championPoints   lastPlayTime  \
# 0                7          293709  1685927577000
# 1                7          260589  1685284583000
# 2                7           91799  1681902265000
# 3                7           91341  1684515780000
# 4                5           80021  1680576909000
# ..             ...             ...            ...
# 141              1             107  1588043269000
# 142              1             106  1568246911000
# 143              1             101  1618779909000
# 144              1              92  1587511242000
# 145              1              88  1649356533000
#
#      championPointsSinceLastLevel  championPointsUntilNextLevel  chestGranted  \
# 0                          272109                             0          True
# 1                          238989                             0          True
# 2                           70199                             0          True
# 3                           69741                             0          True
# 4                           58421                             0          True
# ..                            ...                           ...           ...
# 141                           107                          1693         False
# 142                           106                          1694         False
# 143                           101                          1699         False
# 144                            92                          1708         False
# 145                            88                          1712         False
#
#      tokensEarned                                       summonerId
# 0               0  55MEpu53V7U8jG3j_umw8AuBPQAGpaj7EA7D75inMfyGxqM
# 1               0  55MEpu53V7U8jG3j_umw8AuBPQAGpaj7EA7D75inMfyGxqM
# 2               0  55MEpu53V7U8jG3j_umw8AuBPQAGpaj7EA7D75inMfyGxqM
# 3               0  55MEpu53V7U8jG3j_umw8AuBPQAGpaj7EA7D75inMfyGxqM
# 4               1  55MEpu53V7U8jG3j_umw8AuBPQAGpaj7EA7D75inMfyGxqM
# ..            ...                                              ...
# 141             0  55MEpu53V7U8jG3j_umw8AuBPQAGpaj7EA7D75inMfyGxqM
# 142             0  55MEpu53V7U8jG3j_umw8AuBPQAGpaj7EA7D75inMfyGxqM
# 143             0  55MEpu53V7U8jG3j_umw8AuBPQAGpaj7EA7D75inMfyGxqM
# 144             0  55MEpu53V7U8jG3j_umw8AuBPQAGpaj7EA7D75inMfyGxqM
# 145             0  55MEpu53V7U8jG3j_umw8AuBPQAGpaj7EA7D75inMfyGxqM
#
# [146 rows x 10 columns]

# %%
partida01.head()
# Out:
#    teamId  spell1Id  spell2Id  championId  profileIconId    summonerName  \
# 0     100         4        14          99           5736        Foortune
# 0     100         4        12         150           4864      M1KE TYS0N
# 0     100         4        14         518           5434  AntonyKiller77
# 0     100         4        11         121           5755     PermAcànc3r
# 0     100         7         4          81             11     peneriko123
#
#      bot                                         summonerId  \
# 0  False    55MEpu53V7U8jG3j_umw8AuBPQAGpaj7EA7D75inMfyGxqM
# 0  False    FP95A4NcwZsbHYKATDFJpAMv8wzOpyxHxnfkadid94XNeCQ
# 0  False  VxqE0JuZi21SybY9oHea7IRvliueUMhz4sKn5cTZeCDDS2...
# 0  False  nU5_o77OIGTyHeMPNLC2mQ1L3khgtloykhzXa4HAuGHwuf...
# 0  False  8s9RcWQHEFrV4BjRNloqMVa8I5LCSGknzuzTuCM_cp64YS...
#
#   gameCustomizationObjects                                      perks.perkIds  \
# 0                       []  [8229, 8226, 8210, 8237, 8126, 8106, 5008, 500...
# 0                       []  [8010, 9111, 9104, 8299, 8473, 8451, 5005, 500...
# 0                       []  [8112, 8139, 8138, 8135, 8226, 8237, 5005, 500...
# 0                       []  [8369, 8304, 8321, 8347, 8143, 8135, 5008, 500...
# 0                       []  [8005, 8009, 9103, 8014, 8345, 8304, 5005, 500...
#
#    perks.perkStyle  perks.perkSubStyle
# 0             8200                8100
# 0             8000                8400
# 0             8100                8200
# 0             8300                8100
# 0             8000                8300

# %% [markdown]
# # creacion del df para entrenar

# %%
def detalle_partidas(id_partida:str)->pd.DataFrame:
    
    # Establecemos una coneccion con la API para extraer los datos
    url = f"https://americas.api.riotgames.com/lol/match/v5/matches/{id_partida}?api_key={key_admin}"
    
    try:
        # Establecemos la coneccion con la api
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Error al obtener los datos de la partida {partida}.")
        else:
            None

        # Convertimos el json
        json_info = json.loads(response.text)

        # Comenzamos a transformar el json en un df
        match_information = pd.DataFrame(json_info['info']['participants'])
        
        # Reiniciamos el índice para evitar índices duplicados
        match_information.reset_index(drop=True, inplace=True)

        # Nos fijamos si existe la columna challenges
        if 'challenges'in match_information.columns: 

            # Desglozamos la columna que quedo como un diccionario
            match_information.drop(['challenges'], axis=1, inplace = True)
            
        else:
            None

        # # Eliminamos las columnas que no nos sirven
        # match_information.drop(['perks'], axis=1, inplace = True)

        # Establecemos una columna con el nombre del id de la partida
        match_information['id_game'] = id_partida
        print(f"Se finalizo el proceso para la partida {id_partida}")
        
        # Seleccionamos las columnas que nos queremos quedar
        colstostay = ['summonerId', 'teamId', 'championId', 'perks', 'win']

        return match_information
    
    except Exception as e:
        print(f"Error al obtener los datos de la partida {id_partida}: {e}")
        return pd.DataFrame()
    
detalle_partidas('LA2_1301881670')
# Out:
# Se finalizo el proceso para la partida LA2_1301881670

# %%
A['perks']
# Out:
# 0    {'statPerks': {'defense': 5001, 'flex': 5008, ...
# 1    {'statPerks': {'defense': 5002, 'flex': 5008, ...
# 2    {'statPerks': {'defense': 5002, 'flex': 5008, ...
# 3    {'statPerks': {'defense': 5002, 'flex': 5008, ...
# 4    {'statPerks': {'defense': 5001, 'flex': 5002, ...
# 5    {'statPerks': {'defense': 5003, 'flex': 5003, ...
# 6    {'statPerks': {'defense': 5003, 'flex': 5008, ...
# 7    {'statPerks': {'defense': 5003, 'flex': 5008, ...
# 8    {'statPerks': {'defense': 5002, 'flex': 5008, ...
# 9    {'statPerks': {'defense': 5002, 'flex': 5008, ...
# Name: perks, dtype: object

# %%
## Vamos a ir desglozando perks
# perks
pd.json_normalize(A['perks'])[['statPerks.defense', 'statPerks.flex', 'statPerks.offense']]
#  tenemos el estilo, perk defensivo, el felxible y el ofensivo
# Out:
#    statPerks.defense  statPerks.flex  statPerks.offense
# 0               5001            5008               5007
# 1               5002            5008               5005
# 2               5002            5008               5005
# 3               5002            5008               5005
# 4               5001            5002               5007
# 5               5003            5003               5005
# 6               5003            5008               5005
# 7               5003            5008               5005
# 8               5002            5008               5005
# 9               5002            5008               5008

# %%
# 2 nivel de perks
pd.json_normalize(pd.json_normalize(A['perks'])['styles'])
# Tenemos el estilo primario y el sub estilo, son valores 1 o 0
# Out:
#                                                    0  \
# 0  {'description': 'primaryStyle', 'selections': ...
# 1  {'description': 'primaryStyle', 'selections': ...
# 2  {'description': 'primaryStyle', 'selections': ...
# 3  {'description': 'primaryStyle', 'selections': ...
# 4  {'description': 'primaryStyle', 'selections': ...
# 5  {'description': 'primaryStyle', 'selections': ...
# 6  {'description': 'primaryStyle', 'selections': ...
# 7  {'description': 'primaryStyle', 'selections': ...
# 8  {'description': 'primaryStyle', 'selections': ...
# 9  {'description': 'primaryStyle', 'selections': ...
#
#                                                    1
# 0  {'description': 'subStyle', 'selections': [{'p...
# 1  {'description': 'subStyle', 'selections': [{'p...
# 2  {'description': 'subStyle', 'selections': [{'p...
# 3  {'description': 'subStyle', 'selections': [{'p...
# 4  {'description': 'subStyle', 'selections': [{'p...
# 5  {'description': 'subStyle', 'selections': [{'p...
# 6  {'description': 'subStyle', 'selections': [{'p...
# 7  {'description': 'subStyle', 'selections': [{'p...
# 8  {'description': 'subStyle', 'selections': [{'p...
# 9  {'description': 'subStyle', 'selections': [{'p...

# %%
# 3 nivel de perks
pd.DataFrame(pd.json_normalize(pd.json_normalize(pd.json_normalize(A['perks'])['styles'])[1])['style'], columns=['subStyle'])

# B = pd.json_normalize(pd.json_normalize(pd.json_normalize(A['perks'])['styles'])[1])[['description','style']]
# B.rename(columns={'style':'subStyle'})
# Tenemos las seleciones, y el estilo de las mismas
# Out:
# Empty DataFrame
# Columns: [subStyle]
# Index: []

# %%
pd.json_normalize(pd.json_normalize(pd.json_normalize(A['perks'])['styles'])[0])[['description', 'style']]
# Out:
#     description  style
# 0  primaryStyle   8200
# 1  primaryStyle   8100
# 2  primaryStyle   8200
# 3  primaryStyle   8000
# 4  primaryStyle   8400
# 5  primaryStyle   8400
# 6  primaryStyle   8000
# 7  primaryStyle   8000
# 8  primaryStyle   8000
# 9  primaryStyle   8100

# %%
# 4 nivel de perks
pd.json_normalize(pd.json_normalize(pd.json_normalize(pd.json_normalize(A['perks'])['styles'])[1])['selections'])
# Tenemos los perks primarios y secundartios con sus var, tenemos un 1 oo un 0 en este caso
# Out:
#                                                    0  \
# 0    {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}
# 1  {'perk': 8014, 'var1': 456, 'var2': 0, 'var3': 0}
# 2   {'perk': 8304, 'var1': 10, 'var2': 3, 'var3': 0}
# 3    {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0}
# 4    {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0}
# 5    {'perk': 8304, 'var1': 9, 'var2': 0, 'var3': 0}
# 6  {'perk': 8143, 'var1': 895, 'var2': 0, 'var3': 0}
# 7  {'perk': 8473, 'var1': 707, 'var2': 0, 'var3': 0}
# 8  {'perk': 8233, 'var1': 24, 'var2': 30, 'var3': 0}
# 9   {'perk': 8210, 'var1': 15, 'var2': 0, 'var3': 0}
#
#                                                    1
# 0   {'perk': 8304, 'var1': 10, 'var2': 3, 'var3': 0}
# 1  {'perk': 9104, 'var1': 10, 'var2': 10, 'var3': 0}
# 2  {'perk': 8316, 'var1': 2990, 'var2': 0, 'var3'...
# 3    {'perk': 8304, 'var1': 9, 'var2': 4, 'var3': 5}
# 4    {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}
# 5    {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0}
# 6  {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}
# 7  {'perk': 8242, 'var1': 101, 'var2': 0, 'var3': 0}
# 8   {'perk': 8236, 'var1': 28, 'var2': 0, 'var3': 0}
# 9   {'perk': 8236, 'var1': 48, 'var2': 0, 'var3': 0}

# %%
# 5 nivel de perks
pd.json_normalize(pd.json_normalize(pd.json_normalize(pd.json_normalize(pd.json_normalize(A['perks'])['styles'])[0])['selections'])[0])
# Tenemos el perk con los datos finales
# Out:
#    perk  var1  var2  var3
# 0  8230    30     0     0
# 1  8128  1373    22     0
# 2  8229  3472     0     0
# 3  8008    63     7     0
# 4  8439   771  1453     0
# 5  8437   920   580     0
# 6  8010   530     0     0
# 7  8010   754     0     0
# 8  8008    54     0     0
# 9  8128  1438    20     0
